# %%
# %pylab inline
import numpy as np
import pandas as pd
from collections import defaultdict
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # PGA dataset

# %%
res = pd.read_csv("result.csv")
res
# Out:
#                                                      URL  \
# 0      https://github.com/TestingWithFrank/PublicAuto...
# 1           https://github.com/KnpLabs/KnpMarkdownBundle
# 2      https://github.com/AdilSoomro/Iphone-Tab-in-An...
# 3                https://github.com/guard/guard-brakeman
# 4               https://github.com/felixge/node-paperboy
# 5                           https://github.com/vasi/pixz
# 6                        https://github.com/dom96/jester
# 7                   https://github.com/hokaccha/nodebrew
# 8                 https://github.com/jteeuwen/go-bindata
# 9                   https://github.com/threedaymonk/text
# 10            https://github.com/mhuggins/jquery-countTo
# 11                    https://github.com/danjac/newsmeme
# 12          https://github.com/marcello3d/node-mongolian
# 13                     https://github.com/veged/ometa-js
# 14        https://github.com/couchbase/php-ext-couchbase
# 15            https://github.com/mikeal/node.couchapp.js
# 16                     https://github.com/kriskowal/q-io
# 17              https://github.com/mitsuhiko/flask-oauth
# 18     https://github.com/derekeder/FusionTable-Map-T...
# 19                      https://github.com/kergoth/tslib
# 20                      https://github.com/pfi/pficommon
# 21     https://github.com/sonata-project/SonataNewsBu...
# 22               https://github.com/creationix/jsonparse
# 23            https://github.com/pokeb/ProxyingUIWebView
# 24                 https://github.com/bmc/grizzled-scala
# 25      https://github.com/jaredhanson/passport-facebook
# 26        https://github.com/dokterbob/django-newsletter
# 27        https://github.com/locomotivecms/custom_fields
# 28     https://github.com/masterzen/nginx-upload-prog...
# 29     https://github.com/grails-plugins/grails-datab...
# ...                                                  ...
# 12625                 https://github.com/Ceasar/twosheds
# 12626               https://github.com/yannickl/YLMoment
# 12627               https://github.com/olauzon/capacitor
# 12628           https://github.com/protobuf-c/protobuf-c
# 12629                 https://github.com/openstack/solum
# 12630                https://github.com/ossec/ossec-hids
# 12631                    https://github.com/nicfit/eyed3
# 12632        https://github.com/sonata-project/ecommerce
# 12633                   https://github.com/lmccart/p5.js
# 12634         https://github.com/getify/You-Dont-Know-JS
# 12635           https://github.com/hydroshare/hydroshare
# 12636                    https://github.com/ruslo/hunter
# 12637               https://github.com/amjuarez/bytecoin
# 12638       https://github.com/JetBrains/kotlin-web-site
# 12639  https://github.com/SemanticMediaWiki/SemanticM...
# 12640      https://github.com/puppylinux-woof-CE/woof-CE
# 12641  https://github.com/JamesRandall/WebAPI2Authent...
# 12642         https://github.com/mozilla/fxa-auth-server
# 12643  https://github.com/openfoodfacts/openfoodfacts...
# 12644             https://github.com/opscode/supermarket
# 12645          https://github.com/exoticorn/stockfish-js
# 12646  https://github.com/forcedotcom/SalesforceMobil...
# 12647             https://github.com/berkshelf/berkshelf
# 12648  https://github.com/ivantcholakov/starter-publi...
# 12649  https://github.com/jboss-developer/jboss-eap-q...
# 12650            https://github.com/xpressengine/xe-core
# 12651      https://github.com/mozilla/fxa-content-server
# 12652                  https://github.com/esl/MongooseIM
# 12653                  https://github.com/driftyco/ionic
# 12654            https://github.com/bfroemel/smallchange
#
#                                           SIVA_FILENAMES  FILE_COUNT  \
# 12637      84ca73ea77d50815dd6ce087c8b65980d6c2d2c3.siva        1858
# 12638  3683b5122316ed90ea45c4afc4a4786f41c1f0e4.siva,...         489
# 12639  da8b91569b89d465201a9fba7cb01bb0aa16a057.siva,...        2143
# 12640  07a44aa52ff61671ccf3661582e96e1409275e84.siva,...        4182
# 12641      d6b2d03000dc153e752a67aec9fc2c0529d2ff61.siva         587
# 12642      fd02746d9857f456e49bb1a14bdf2ca81d7f3fa6.siva         326
# 12643  5e9979518e5eebde6f075cf782d38a9012aebc0c.siva,...        2393
# 12644      88e6a08032212b0f7e676a5d5729fe1e6d1c2bdc.siva        1113
# 12645  8faab83df35082210878a44495721cc2ade76b7e.siva,...          70
# 12646  5028065932467bb308a6ad5165841c163c63feb5.siva,...         588
# 12647  25612cf3601733a37727f1f490e69fdf48963d36.siva,...         209
# 12648      e5f4421b0bcd5d36c7c843d23857a260db8bb1b1.siva        9978
# 12649  778c99c47a40efb69bc428b7353c6cb32fa38e26.siva,...        3410
# 12650  2569c554ce3077cfd73a8a18176fd99268ffc82e.siva,...        3708
# 12651      c635fff98c80aa200b2835b5ebfa348d6dcfec96.siva        1068
# 12652  58e6ff32a09c8d427fd99797d2a727a3d1d00de3.siva,...         846
# 12653  30f8a5e65cae19c8bd45606e8238d7f0bc005b7d.siva,...        2359
# 12654  4405b78d6059e536c36974088a8ed4d9f0f29898.siva,...         382
#
#                                                    LANGS  \
# 0                       C,Markdown,Objective-C,Ruby,Text
# 1        ApacheConf,HTML,JSON,Markdown,PHP,Text,XML,YAML
# 2      Batchfile,Gradle,INI,Java,Markdown,Shell,Text,XML
# 3        Gherkin,HTML,JavaScript,Markdown,Ruby,Text,YAML
# 4                HTML,JSON,JavaScript,Markdown,Text,YAML
# 5      AsciiDoc,C,M4Sugar,Makefile,Markdown,Shell,Tex...
# 6                                 HTML,Markdown,Nim,Text
# 7                      HTML,Markdown,Perl,Text,YAML,fish
# 8                Go,Makefile,Markdown,Text,Unity3D Asset
# 9                                CSV,RDoc,Ruby,Text,YAML
# 10                    HTML,JSON,JavaScript,Markdown,Text
# 11     CSS,Gettext Catalog,HTML,INI,JSON,JavaScript,P...
# 12     Ant Build System,JSON,JavaScript,Markdown,Text...
# 13           JSON,JavaScript,Makefile,Markdown,Text,YAML
# 14     C,INI,JavaScript,M4Sugar,Markdown,PHP,Perl,Pod...
# 15                CSS,HTML,JSON,JavaScript,Markdown,Text
# 16                    JSON,JavaScript,Markdown,Text,YAML
# 17     Batchfile,CSS,HTML,INI,Makefile,Python,Text,re...
# 18                 CSS,HTML,JavaScript,Markdown,SVG,Text
# 19     C,C++,CSS,HTML,M4Sugar,Makefile,Markdown,Roff,...
# 20     Batchfile,C,C++,Haskell,Makefile,PHP,Python,Ru...
# 21     INI,JSON,Makefile,Markdown,PHP,Python,Shell,Te...
# 22                         JSON,JavaScript,Markdown,Text
# 23                       C,Markdown,Objective-C,Text,XML
# 24                     CSS,INI,Markdown,Scala,Shell,YAML
# 25           JSON,JavaScript,Makefile,Markdown,Text,YAML
# 26     Batchfile,CSV,Gettext Catalog,Graphviz (DOT),H...
# 27                               Markdown,Ruby,Text,YAML
# 28                                 C,Makefile,Shell,Text
# 29     AsciiDoc,Batchfile,Gradle,Groovy,INI,Markdown,...
# ...                                                  ...
# 12625  Batchfile,INI,Makefile,Python,Text,YAML,reStru...
# 12626      Markdown,Objective-C,Ruby,Shell,Text,XML,YAML
# 12627                         Clojure,Markdown,Text,YAML
# 12628  C,C++,CMake,M4Sugar,Makefile,Markdown,Protocol...
# 12629  Dockerfile,Gettext Catalog,Go,INI,JSON,Makefil...
# 12630  Ada,Assembly,Batchfile,C,C#,C++,CMake,CSS,DIGI...
# 12631  Batchfile,CSS,EBNF,INI,Makefile,Python,Roff,Sh...
# 12632  Ant Build System,CSS,INI,JSON,JavaScript,Makef...
# 12633  CSS,CSV,GLSL,HTML,Handlebars,INI,JSON,JavaScri...
# 12634                                      Markdown,Text
# 12635  Batchfile,CSS,CSV,Dockerfile,HTML,INI,JSON,Jav...
# 12636  Batchfile,C,C++,CMake,Cuda,Lex,Makefile,Object...
# 12637  Batchfile,C,C++,CMake,CSS,Dockerfile,HTML,INI,...
# 12638  CSS,Dockerfile,HTML,HTML+Django,JSON,JSON5,Jav...
# 12639  CSS,CSV,INI,JSON,JavaScript,Markdown,PHP,SQL,S...
# 12640  C,CSS,DIGITAL Command Language,Diff,Gettext Ca...
# 12641  ASP,C#,CSS,HTML,JavaScript,Markdown,Pascal,Pow...
# 12642  HTML,Handlebars,INI,JSON,JavaScript,Makefile,M...
# 12643  ActionScript,CSS,CSV,Gettext Catalog,HTML,INI,...
# 12644  CSS,HCL,HTML,HTML+ERB,JSON,JavaScript,Makefile...
# 12645  C,C++,CSS,HTML,INI,JavaScript,Makefile,Markdow...
# 12646  Batchfile,Dockerfile,Gradle,HTML,INI,JSON,Java...
# 12647           Gherkin,HTML+ERB,Markdown,Ruby,Text,YAML
# 12648  ApacheConf,C,CSS,CSV,Diff,Dockerfile,HTML,HTML...
# 12649  AsciiDoc,Batchfile,CSS,GLSL,HTML,HTML+Django,I...
# 12650  ApacheConf,CSS,HTML,INI,JSON,JSON5,JavaScript,...
# 12651  CSS,HTML,HTML+Django,INI,JSON,JavaScript,Markd...
# 12652  API Blueprint,ASN.1,C,C++,CSS,CSV,Erlang,Gette...
# 12653  CSS,HTML,INI,JSON,JavaScript,Markdown,PHP,Ruby...
# 12654  C,C++,CSV,INI,JSON,Makefile,Markdown,NSIS,Obje...
#
#                                         LANGS_BYTE_COUNT  \
# 0                                214,1899,55196,1545,573
# 1                135,8708,1331,10961,48184,1068,4891,902
# 2                 2404,841,595,6104,2427,4971,1078,14201
# 3                   369,10291,234380,6360,38138,1260,879
# 4                            310,642,10824,4040,1084,170
# 5               2845,62560,16140,1031,4183,1167,2260,343
# 6                                     36,6795,44463,1070
# 7                          2857,7643,47411,1103,153,1752
# 8                                80252,1112,10306,169,60
# 9                           20575,1190,50058,354916,1807
# 12630  1681,2390,0,78022,879,599,186,105,0,0,8435,0,0...
# 12631                    0,576,0,0,373,13097,0,0,0,100,0
# 12632   0,47,0,90,102,168,571,22889,16,0,0,0,0,2164,62,0
# 12633      227,0,0,1903,0,0,17658,54843,116,0,0,0,161,12
# 12634                                            21463,0
# 12635  0,41983,0,0,15987,0,123,41871,157,10,1027,7684...
# 12636  0,12302,8343,31689,0,0,181,31,0,932,0,0,0,0,15...
# 12637  0,13471,222741,1141,78,0,786,0,0,14223,95,0,17...
# 12638  200,0,1172,0,90,0,4410,12944,930,0,0,0,0,21904...
# 12639      2668,0,0,56917,7824,4731,140116,6,0,0,2246,81
# 12640  3425,1022,0,0,0,1129,0,60,352,123,0,0,0,0,0,0,...
# 12641        0,2628,5886,130,14951,63,0,212,0,0,0,302258
# 12642            1653,0,0,10882,40120,22,4553,230,0,0,83
# 12643  66,4107,0,0,13563,0,505,57380,0,1367,0,278,350...
# 12644  4668,0,182,0,1341,739,72,1278,0,0,20738,0,0,0,...
# 12645                       0,5301,1,209,0,332,379,112,0
# 12646     0,0,0,4,0,214,36614,1470,466,73,0,0,0,2917,150
# 12647                             3010,0,1488,8508,0,113
# 12648  0,858,138094,0,0,0,114618,0,0,0,0,4138,101000,...
# 12649  1999,0,67564,0,28221,0,0,372,22470,0,130006,0,...
# 12650  0,23730,22714,0,48,0,63440,1295,104156,0,0,0,4...
# 12651            26,383,0,0,11684,86290,4584,0,0,0,0,161
# 12652  0,0,168,22,3411,0,105651,0,2661,0,3756,186,869...
# 12653  377,14169,0,15243,1483,2738,0,13,0,0,0,0,53285...
# 12654  198,25285,0,0,326,0,112,133,79,589,0,0,0,0,0,0...
#
#                                      COMMENT_LINES_COUNT  \
# 0                                             0,0,49,0,0
# 1                                      0,0,0,0,273,0,1,3
# 2                                       0,0,0,26,0,0,0,9
# 3                                      0,3,469,0,215,0,7
# 4                                           0,0,21,0,0,0
# 5                                       0,55,0,2,0,0,0,0
# 6                                              0,0,141,0
# 7                                           0,0,16,0,0,0
# 8                                            499,0,0,0,0
# 9                                           0,0,145,0,11
# 10                                             5,0,6,0,0
# 11                                  211,0,7,0,0,17,201,0
# 12                                       0,0,301,0,0,0,0
# 13                                        0,2111,0,0,0,0
# 14                            1218,0,0,0,0,935,0,0,0,0,0
# 15                                        0,0,0,1957,0,0
# 16                                           0,819,0,0,0
# 17                                     0,0,0,0,4,322,0,0
# 18                                        13,18,37,0,0,0
# 19                             8060,0,0,2,0,63,0,0,0,0,0
# 20                          0,0,2737,20,4,2,229,55,0,0,0
# 21                          0,0,8,0,2100,162,0,0,0,2,4,0
# 22                                              0,22,0,0
# 23                                          0,0,1049,0,0
# 24                                        4,0,0,4765,0,5
# 25                                         0,178,0,0,0,0
# 26                         0,0,0,0,2,0,0,0,6,898,2,0,5,0
# 27                                             0,733,0,0
# 28                                              88,0,0,0
# 29                                  0,0,0,1312,0,0,0,0,0
# ...                                                  ...
# 12625                                    0,0,5,420,0,0,0
# 12626                                    0,653,0,0,0,0,0
# 12627                                            0,0,0,0
# 12628                         819,908,7,0,24,0,0,0,0,7,3
# 12629                   0,0,0,0,0,5,0,0,5516,0,0,0,0,0,0
# 12630  560,1836,0,18296,506,136,31,0,0,0,26,0,0,139,0...
# 12631                          0,69,0,0,7,2282,0,0,0,3,0
# 12632            0,3,0,0,16,8,0,14478,162,0,0,0,0,18,4,0
# 12633                  24,0,0,70,0,0,0,31667,0,0,0,0,0,6
# 12634                                                0,0
# 12635  0,1643,0,0,235,0,0,5565,0,6,0,17603,37,6108,0,...
# 12636     0,2314,1374,5379,0,0,6,0,0,333,0,0,0,0,68,13,0
# 12637  0,2303,39417,208,1,0,7,0,0,6956,5,0,256,0,156,...
# 12638               9,0,19,0,0,0,458,0,18,0,0,0,0,0,0,11
# 12639                  625,0,0,0,3374,0,57243,0,0,0,7,15
# 12640       714,101,0,0,0,21,0,13,5,0,0,0,0,0,0,0,29,0,0
# 12641                   0,474,45,0,7524,0,0,333,0,0,0,55
# 12642                        196,0,0,0,2013,8,0,62,0,0,4
# 12643  12,492,0,0,164,0,0,12946,0,0,0,129,2819,0,0,0,...
# 12644          79,0,3,0,0,258,8,0,0,0,3902,0,0,0,4,0,265
# 12645                             0,1493,1,0,0,25,76,0,0
# 12646              0,0,0,0,0,0,21754,451,0,8,0,0,0,156,0
# 12647                                    11,0,0,1828,0,8
# 12648  0,185,113451,0,0,0,452,0,0,0,0,0,24798,0,0,0,0...
# 12649  0,0,3725,0,928,0,0,0,16863,0,46606,0,28,0,0,6,...
# 12650           0,852,2291,0,0,0,9260,0,42570,1,0,0,31,2
# 12651                     23,51,0,0,0,15060,0,0,0,0,0,18
# 12652  0,0,54,17,12,0,16915,0,47,0,745,5,0,0,7,2032,1...
# 12653               40,93,0,0,321,0,0,1,0,0,0,0,14361,10
# 12654    56,2356,0,0,0,0,0,13,0,639,0,0,0,0,0,0,0,29,0,0
#
#                                                  LICENSE
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                        Apache-2.0:0.980,ECL-2.0:0.742
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19     LGPL-2.1-only:0.959,LGPL-2.1-or-later:0.959,de...
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26     AGPL-3.0-only:0.976,AGPL-3.0-or-later:0.976,de...
# 27                                                   NaN
# 28                                                   NaN
# 29                        Apache-2.0:0.986,ECL-2.0:0.748
# ...                                                  ...
# 12625                                                NaN
# 12626                                                NaN
# 12627                        CPL-1.0:0.854,EPL-1.0:0.954
# 12628                                                NaN
# 12629                                                NaN
# 12630                                                NaN
# 12631  GPL-3.0-only:0.976,GPL-3.0-or-later:0.976,depr...
# 12632                                                NaN
# 12633  LGPL-2.1-only:0.732,LGPL-2.1-or-later:0.732,de...
# 12634  CC-BY-4.0:0.755,CC-BY-NC-4.0:0.850,CC-BY-NC-ND...
# 12635                                                NaN
# 12636                                                NaN
# 12637  LGPL-3.0-only:0.973,LGPL-3.0-or-later:0.973,de...
# 12638                     Apache-2.0:0.979,ECL-2.0:0.740
# 12639                                                NaN
# 12640  GPL-2.0-only:0.895,GPL-2.0-or-later:0.895,depr...
# 12641                                                NaN
# 12642  MPL-2.0:0.910,MPL-2.0-no-copyleft-exception:0.910
# 12643  AGPL-3.0-only:0.976,AGPL-3.0-or-later:0.976,de...
# 12644                     Apache-2.0:0.981,ECL-2.0:0.742
# 12645  GPL-3.0-only:0.976,GPL-3.0-or-later:0.976,depr...
# 12646                                                NaN
# 12647                                                NaN
# 12648                                                NaN
# 12649                     Apache-2.0:0.795,ECL-2.0:0.669
# 12650  LGPL-2.1-only:0.642,LGPL-2.1-or-later:0.642,de...
# 12651  MPL-2.0:0.909,MPL-2.0-no-copyleft-exception:0.909
# 12652                                                NaN
# 12653                                                NaN
# 12654                                                NaN
#
# [12655 rows x 14 columns]

# %% [markdown]
# # Number of forks

# %%
total_fork_count = res["FORK_COUNT"].sum()
print("Number of forks :", total_fork_count)
# Out:
# Number of forks : 694

# %% [markdown]
# # Number of languages

# %%
langs = set()
for row_langs in res["LANGS"]:
    langs.update(row_langs.split(","))
print("Number of languages :", len(langs))
# Out:
# Number of languages : 348

# %% [markdown]
# # Quantity per language

# %%
langs_bytes = defaultdict(int)
langs_lines = defaultdict(int)
langs_files = defaultdict(int)

for i in range(len(res)):
    row = res.iloc[i]
    langs = row.LANGS.split(",")
    langs_bytes_count = row.LANGS_BYTE_COUNT.split(",")
    langs_lines_count = row.LANGS_LINES_COUNT.split(",")
    langs_files_count = row.LANGS_FILES_COUNT.split(",")
    
    for l in langs:
        langs_bytes[l] += int(langs_bytes_count[langs.index(l)])
        langs_lines[l] += int(langs_lines_count[langs.index(l)])
        langs_files[l] += int(langs_files_count[langs.index(l)])

# %%
langs_files
# Out:
# defaultdict(int,
#             {'1C Enterprise': 3,
#              'ABAP': 2,
#              'ABNF': 1,
#              'AGS Script': 6,
#              'ANTLR': 39,
#              'API Blueprint': 74,
#              'ASN.1': 153,
#              'ASP': 707,
#              'ActionScript': 12475,
#              'Ada': 150,
#              'Adobe Font Metrics': 137,
#              'Agda': 180,
#              'Alpine Abuild': 1,
#              'Ant Build System': 601,
#              'ApacheConf': 895,
#              'Apex': 143,
#              'AppleScript': 101,
#              'Arc': 69,
#              'Arduino': 948,
#              'AsciiDoc': 1380,
#              'AspectJ': 41,
#              'Assembly': 2107,
#              'Augeas': 7,
#              'AutoHotkey': 58,
#              'AutoIt': 2,
#              'Awk': 227,
#              'Batchfile': 3325,
#              'BitBake': 1,
#              'Blade': 441,
#              'BlitzMax': 1,
#              'Bluespec': 1,
#              'Boo': 6,
#              'Brainfuck': 26,
#              'Brightscript': 146,
#              'Bro': 15,
#              'C': 144797,
#              'C#': 61697,
#              'C++': 156016,
#              'C2hs Haskell': 164,
#              'CLIPS': 7,
#              'CMake': 6879,
#              'COBOL': 23,
#              'COLLADA': 510,
#              'CSON': 14,
#              'CSS': 34537,
#              'CSV': 2718,
#              "Cap'n Proto": 4,
#              'CartoCSS': 24,
#              'Ceylon': 30,
#              'Clarion': 3,
#              'Clean': 1,
#              'Clojure': 1547,
#              'Closure Templates': 35,
#              'CoffeeScript': 7873,
#              'ColdFusion': 169,
#              'ColdFusion CFC': 389,
#              'Common Lisp': 1023,
#              'Coq': 245,
#              'Creole': 1,
#              'Csound': 5,
#              'Csound Document': 234,
#              'Cuda': 899,
#              'Cycript': 1,
#              'Cython': 1158,
#              'D': 479,
#              'DIGITAL Command Language': 322,
#              'DNS Zone': 20,
#              'DTrace': 60,
#              'Darcs Patch': 1,
#              'Dart': 1699,
#              'Diff': 3015,
#              'Dockerfile': 1006,
#              'Dogescript': 60,
#              'Dylan': 1,
#              'E': 2,
#              'EBNF': 8,
#              'ECL': 1,
#              'EJS': 781,
#              'Eagle': 106,
#              'Elixir': 1041,
#              'Elm': 99,
#              'Emacs Lisp': 1208,
#              'EmberScript': 4,
#              'Erlang': 4077,
#              'F#': 1747,
#              'FLUX': 4,
#              'Factor': 1,
#              'Fancy': 1,
#              'Fantom': 1,
#              'Filterscript': 3,
#              'Forth': 49,
#              'Fortran': 749,
#              'FreeMarker': 714,
#              'Frege': 315,
#              'G-code': 15,
#              'GAP': 44,
#              'GCC Machine Description': 134,
#              'GDB': 62,
#              'GLSL': 955,
#              'GN': 34,
#              'Genshi': 2,
#              'Gentoo Ebuild': 17,
#              'Gerber Image': 45,
#              'Gettext Catalog': 12313,
#              'Gherkin': 1770,
#              'Gnuplot': 63,
#              'Go': 35753,
#              'Golo': 152,
#              'Gosu': 2,
#              'Gradle': 2790,
#              'Graph Modeling Language': 9,
#              'GraphQL': 67,
#              'Graphviz (DOT)': 963,
#              'Groovy': 5416,
#              'Groovy Server Pages': 248,
#              'HCL': 13,
#              'HLSL': 114,
#              'HTML': 129750,
#              'HTML+Django': 892,
#              'HTML+EEX': 27,
#              'HTML+ERB': 7337,
#              'HTML+PHP': 1719,
#              'HTTP': 39,
#              'Hack': 196,
#              'Haml': 3405,
#              'Handlebars': 2248,
#              'Harbour': 2,
#              'Haskell': 5622,
#              'Haxe': 3864,
#              'Hy': 111,
#              'IDL': 124,
#              'INI': 19879,
#              'IRC log': 1,
#              'Idris': 639,
#              'Inno Setup': 244,
#              'Io': 5,
#              'Ioke': 1,
#              'Isabelle ROOT': 1,
#              'JFlex': 20,
#              'JSON': 64035,
#              'JSON5': 163,
#              'JSONLD': 72,
#              'JSONiq': 14,
#              'JSX': 776,
#              'Jasmin': 51,
#              'Java': 249343,
#              'Java Server Pages': 2628,
#              'JavaScript': 258075,
#              'Jison': 4,
#              'Julia': 1557,
#              'Jupyter Notebook': 798,
#              'KiCad Layout': 396,
#              'KiCad Legacy Layout': 1,
#              'KiCad Schematic': 12,
#              'Kit': 1,
#              'Kotlin': 1410,
#              'LLVM': 146,
#              'Lasso': 3,
#              'Latte': 155,
#              'Less': 10114,
#              'Lex': 87,
#              'LilyPond': 182,
#              'Limbo': 124,
#              'Linker Script': 608,
#              'Liquid': 42,
#              'Literate CoffeeScript': 77,
#              'Literate Haskell': 198,
#              'LiveScript': 105,
#              'Logos': 237,
#              'Logtalk': 1,
#              'Lua': 8892,
#              'M': 33,
#              'M4': 37,
#              'M4Sugar': 2792,
#              'MAXScript': 6,
#              'Makefile': 16015,
#              'Mako': 612,
#              'Markdown': 76829,
#              'Marko': 3,
#              'Mask': 39,
#              'Mathematica': 35,
#              'Matlab': 2996,
#              'Maven POM': 5189,
#              'Max': 21,
#              'MediaWiki': 184,
#              'Mercury': 6,
#              'Meson': 126,
#              'Metal': 1,
#              'Modelica': 22,
#              'Modula-2': 4,
#              'Module Management System': 19,
#              'Moocode': 2,
#              'MoonScript': 2,
#              'Myghty': 3,
#              'NSIS': 427,
#              'Nemerle': 1,
#              'NewLisp': 39,
#              'Nginx': 76,
#              'Nim': 80,
#              'Ninja': 25,
#              'Nix': 238,
#              'Nu': 5,
#              'OCaml': 3891,
#              'Objective-C': 44240,
#              'Objective-C++': 838,
#              'Objective-J': 100,
#              'Opa': 11,
#              'OpenCL': 141,
#              'OpenEdge ABL': 31,
#              'OpenRC runscript': 75,
#              'OpenSCAD': 164,
#              'OpenType Feature File': 190,
#              'Org': 332,
#              'Oz': 1,
#              'PAWN': 30,
#              'PHP': 150002,
#              'PLSQL': 1259,
#              'PLpgSQL': 911,
#              'POV-Ray SDL': 707,
#              'Parrot Internal Representation': 2,
#              'Pascal': 711,
#              'Perl': 18601,
#              'Perl 6': 1565,
#              'Pic': 3,
#              'Pickle': 68,
#              'PigLatin': 73,
#              'Pod': 951,
#              'PogoScript': 148,
#              'PostScript': 297,
#              'PowerBuilder': 2,
#              'PowerShell': 1957,
#              'Processing': 1130,
#              'Prolog': 238,
#              'Protocol Buffer': 806,
#              'Public Key': 255,
#              'Pug': 1254,
#              'Puppet': 2341,
#              'Pure Data': 1076,
#              'PureBasic': 3,
#              'PureScript': 633,
#              'Python': 124682,
#              'Python traceback': 3,
#              'QML': 515,
#              'QMake': 691,
#              'R': 5405,
#              'RAML': 47,
#              'RDoc': 264,
#              'REXX': 2,
#              'RHTML': 228,
#              'RMarkdown': 140,
#              'RPM Spec': 333,
#              'Racket': 359,
#              'Ragel': 28,
#              'Raw token data': 122,
#              'Rebol': 133,
#              'Redcode': 1,
#              'Regular Expression': 5,
#              "Ren'Py": 3,
#              'RenderScript': 1,
#              'RobotFramework': 36,
#              'Roff': 6048,
#              'Ruby': 90055,
#              'Rust': 7023,
#              'SAS': 476,
#              'SCSS': 10806,
#              'SMT': 6,
#              'SPARQL': 1881,
#              'SQF': 798,
#              'SQL': 3631,
#              'SQLPL': 784,
#              'SVG': 28512,
#              'Sage': 1,
#              'SaltStack': 409,
#              'Sass': 1000,
#              'Scala': 18690,
#              'Scaml': 25,
#              'Scheme': 5245,
#              'Scilab': 36,
#              'ShaderLab': 57,
#              'Shell': 37050,
#              'ShellSession': 1,
#              'Slash': 67,
#              'Slim': 788,
#              'Smalltalk': 924,
#              'Smarty': 3217,
#              'SourcePawn': 27,
#              'Spline Font Database': 8,
#              'Squirrel': 204,
#              'Stan': 1215,
#              'Standard ML': 2065,
#              'Stata': 12,
#              'Stylus': 829,
#              'SubRip Text': 96,
#              'Sublime Text Config': 622,
#              'SuperCollider': 182,
#              'Swift': 2029,
#              'SystemVerilog': 152,
#              'TOML': 502,
#              'Tcl': 473,
#              'Tcsh': 10,
#              'TeX': 4281,
#              'Tea': 1,
#              'Terra': 547,
#              'Text': 78794,
#              'Textile': 65,
#              'Thrift': 79,
#              'Turing': 30,
#              'Turtle': 1667,
#              'Twig': 1808,
#              'Type Language': 8,
#              'TypeScript': 6449,
#              'Unity3D Asset': 4998,
#              'Unix Assembly': 3658,
#              'UrWeb': 677,
#              'VCL': 73,
#              'VHDL': 790,
#              'Vala': 555,
#              'Verilog': 1031,
#              'Vim script': 1204,
#              'Visual Basic': 436,
#              'Volt': 118,
#              'Vue': 224,
#              'Wavefront Material': 84,
#              'Wavefront Object': 253,
#              'Web Ontology Language': 13,
#              'WebAssembly': 8,
#              'World of Warcraft Addon Data': 1,
#              'XML': 124060,
#              'XPM': 658,
#              'XPages': 3,
#              'XProc': 8,
#              'XQuery': 27,
#              'XS': 36,
#              'XSLT': 1733,
#              'Xtend': 82,
#              'YAML': 39041,
#              'YANG': 6,
#              'Yacc': 134,
#              'desktop': 1082,
#              'eC': 66,
#              'edn': 34,
#              'fish': 78,
#              'mupad': 45,
#              'nesC': 632,
#              'ooc': 403,
#              'reStructuredText': 22791,
#              'wisp': 28,
#              'xBase': 29})

# %%
results = []
for lang, _ in langs_files.items():
    results.append((lang, langs_files[lang], langs_lines[lang], langs_bytes[lang]))
results
# Out:
# [('C', 144797, 54522438, 1827653586),
#  ('Markdown', 76829, 10289405, 428024795),
#  ('Objective-C', 44240, 5709289, 207059642),
#  ('Ruby', 90055, 7390411, 253525221),
#  ('Text', 78794, 42749997, 1942524052),
#  ('ApacheConf', 895, 25420, 910753),
#  ('HTML', 129750, 28014694, 1396115755),
#  ('JSON', 64035, 31782829, 1398652042),
#  ('PHP', 150002, 25112063, 885314702),
#  ('XML', 124060, 41141568, 2308770405),
#  ('YAML', 39041, 3198565, 164351763),
#  ('Batchfile', 3325, 208538, 6114497),
#  ('Gradle', 2790, 128068, 3761315),
#  ('INI', 19879, 1233262, 47845862),
#  ('Java', 249343, 37973660, 1321784643),
#  ('Shell', 37050, 6277121, 185067364),
#  ('Gherkin', 1770, 160783, 6496025),
#  ('JavaScript', 258075, 114576846, 5185386965),
#  ('AsciiDoc', 1380, 211614, 8033679),
#  ('M4Sugar', 2792, 1447128, 50495517),
#  ('Makefile', 16015, 1395395, 49370192),
#  ('Nim', 80, 9944, 334258),
#  ('Perl', 18601, 3223969, 140075798),
#  ('fish', 78, 4842, 154454),
#  ('Go', 35753, 11173501, 352909472),
#  ('Unity3D Asset', 4998, 329400, 16918254),
#  ('CSV', 2718, 10963243, 808682328),
#  ('RDoc', 264, 42366, 1550121),
#  ('CSS', 34537, 13625190, 610159098),
#  ('Gettext Catalog', 12313, 13459308, 381510653),
#  ('Python', 124682, 22927920, 959218946),
#  ('Ant Build System', 601, 79756, 3211798),
#  ('Pod', 951, 201451, 6669036),
#  ('reStructuredText', 22791, 2206069, 76015696),
#  ('SVG', 28512, 5749475, 622841801),
#  ('C++', 156016, 47093520, 1612789922),
#  ('Roff', 6048, 1157502, 37142408),
#  ('Haskell', 5622, 964989, 34397205),
#  ('Twig', 1808, 97729, 4041680),
#  ('Scala', 18690, 1828475, 65391623),
#  ('Graphviz (DOT)', 963, 43587, 1437609),
#  ('SQL', 3631, 1711097, 128854640),
#  ('Groovy', 5416, 557502, 19568986),
#  ('Emacs Lisp', 1208, 408770, 16004030),
#  ('Org', 332, 72990, 2597864),
#  ('Racket', 359, 51349, 1720357),
#  ('Scheme', 5245, 1751660, 64196145),
#  ('Perl 6', 1565, 345044, 9359585),
#  ('Common Lisp', 1023, 249017, 9175911),
#  ('Dockerfile', 1006, 25410, 770763),
#  ('Diff', 3015, 1185969, 39653219),
#  ('MediaWiki', 184, 33261, 1501258),
#  ('NSIS', 427, 101114, 3426177),
#  ('desktop', 1082, 13416, 375401),
#  ('Swift', 2029, 290000, 10473845),
#  ('TypeScript', 6449, 929810, 32250779),
#  ('Pug', 1254, 55070, 2252890),
#  ('Stylus', 829, 79145, 1682729),
#  ('CMake', 6879, 504074, 16682065),
#  ('Maven POM', 5189, 591832, 20432121),
#  ('C#', 61697, 8225384, 308975143),
#  ('Textile', 65, 11282, 567678),
#  ('ActionScript', 12475, 2709155, 91486516),
#  ('AspectJ', 41, 3381, 127588),
#  ('Groovy Server Pages', 248, 21372, 825388),
#  ('Java Server Pages', 2628, 223752, 8425506),
#  ('Mako', 612, 38987, 1064635),
#  ('HTML+ERB', 7337, 331730, 12290333),
#  ('Lex', 87, 20041, 581097),
#  ('Yacc', 134, 64157, 1798507),
#  ('CoffeeScript', 7873, 867770, 29422690),
#  ('EJS', 781, 30610, 1103513),
#  ('HTML+Django', 892, 94161, 3991807),
#  ('Handlebars', 2248, 63380, 2331882),
#  ('Less', 10114, 1525493, 36599666),
#  ('SCSS', 10806, 1230443, 31569707),
#  ('JSX', 776, 87866, 2837685),
#  ('Sass', 1000, 75792, 1629335),
#  ('Vim script', 1204, 179721, 6536162),
#  ('R', 5405, 798987, 43444505),
#  ('Rebol', 133, 24793, 726069),
#  ('Cython', 1158, 187816, 6368495),
#  ('Ada', 150, 62022, 2356169),
#  ('Agda', 180, 20293, 689257),
#  ('D', 479, 175676, 4876422),
#  ('Lua', 8892, 1517328, 52468046),
#  ('Matlab', 2996, 287381, 10616144),
#  ('Prolog', 238, 102150, 3422846),
#  ('RHTML', 228, 5470, 152035),
#  ('Tcl', 473, 152439, 4757815),
#  ('Literate Haskell', 198, 23938, 883078),
#  ('PostScript', 297, 646504, 43041805),
#  ('ASP', 707, 29054, 1135710),
#  ('PowerShell', 1957, 299387, 9250442),
#  ('XSLT', 1733, 541040, 21830405),
#  ('Erlang', 4077, 911028, 34273762),
#  ('GAP', 44, 100752, 2352432),
#  ('Mathematica', 35, 45611, 1989128),
#  ('RPM Spec', 333, 62390, 2256836),
#  ('Mask', 39, 857, 11961),
#  ('Clojure', 1547, 227705, 8454865),
#  ('PLSQL', 1259, 31045, 1083176),
#  ('PLpgSQL', 911, 265661, 22179301),
#  ('SQLPL', 784, 70766, 4240737),
#  ('FreeMarker', 714, 52873, 2770147),
#  ('Haml', 3405, 85613, 3172798),
#  ('Sublime Text Config', 622, 122479, 4277447),
#  ('Awk', 227, 23122, 719304),
#  ('GDB', 62, 3687, 97760),
#  ('HTML+PHP', 1719, 96896, 3986782),
#  ('Volt', 118, 4878, 208048),
#  ('Assembly', 2107, 1454793, 28439290),
#  ('Turtle', 1667, 793960, 37748244),
#  ('Linker Script', 608, 73893, 1894972),
#  ('mupad', 45, 5566, 226829),
#  ('F#', 1747, 398046, 15619618),
#  ('QMake', 691, 33172, 975547),
#  ('XPM', 658, 122267, 8217944),
#  ('Arduino', 948, 131963, 3934727),
#  ('Eagle', 106, 514073, 30458413),
#  ('OpenSCAD', 164, 14859, 424982),
#  ('Puppet', 2341, 126988, 4396548),
#  ('JSON5', 163, 1788, 31950),
#  ('Objective-C++', 838, 269839, 8680877),
#  ('Rust', 7023, 829778, 29911982),
#  ('TOML', 502, 11317, 249402),
#  ('M4', 37, 6212, 202634),
#  ('Meson', 126, 6492, 191689),
#  ('Smarty', 3217, 272979, 11748192),
#  ('TeX', 4281, 751433, 28489307),
#  ('Forth', 49, 31689, 566014),
#  ('Parrot Internal Representation', 2, 178, 2922),
#  ('Protocol Buffer', 806, 114950, 4091393),
#  ('Thrift', 79, 12574, 418703),
#  ('SuperCollider', 182, 10586, 310239),
#  ('Inno Setup', 244, 57639, 2562393),
#  ('EBNF', 8, 669, 21515),
#  ('GLSL', 955, 53782, 1532209),
#  ('Haxe', 3864, 484341, 13157570),
#  ('Public Key', 255, 28310, 1506672),
#  ('Closure Templates', 35, 2017, 53913),
#  ('Coq', 245, 73609, 2910132),
#  ('OCaml', 3891, 756742, 25668296),
#  ('Standard ML', 2065, 1798168, 58408430),
#  ('Verilog', 1031, 65758, 1856306),
#  ('ColdFusion', 169, 4898, 197158),
#  ('ColdFusion CFC', 389, 42197, 1896899),
#  ('PigLatin', 73, 3384, 135783),
#  ('RMarkdown', 140, 36255, 1385021),
#  ('OpenCL', 141, 9655, 284140),
#  ('Unix Assembly', 3658, 652772, 15713525),
#  ('ooc', 403, 49700, 1463769),
#  ('Jison', 4, 816, 19700),
#  ('Creole', 1, 348, 18054),
#  ('AppleScript', 101, 5755, 196617),
#  ('Nginx', 76, 5142, 142049),
#  ('VCL', 73, 4979, 184566),
#  ('Fortran', 749, 523237, 19766433),
#  ('HLSL', 114, 19524, 671573),
#  ('Gnuplot', 63, 10877, 255858),
#  ('Jupyter Notebook', 798, 811362, 191872039),
#  ('LiveScript', 105, 12024, 405432),
#  ('PAWN', 30, 14613, 1570425),
#  ('Vala', 555, 148087, 4834295),
#  ('Pascal', 711, 167344, 5690757),
#  ('QML', 515, 45671, 1433847),
#  ('Wavefront Object', 253, 1836937, 50816340),
#  ('JSONLD', 72, 62296, 2659512),
#  ('API Blueprint', 74, 46235, 1432199),
#  ('COLLADA', 510, 269825, 38983132),
#  ('VHDL', 790, 57978, 1661385),
#  ('CLIPS', 7, 249, 12497),
#  ('DIGITAL Command Language', 322, 75602, 2447467),
#  ('Module Management System', 19, 2959, 105066),
#  ('SAS', 476, 141228, 4671326),
#  ('Turing', 30, 3307, 1123487),
#  ('Blade', 441, 20877, 696789),
#  ('Nix', 238, 16108, 477471),
#  ('Brainfuck', 26, 3044, 90451),
#  ('Limbo', 124, 6156, 251258),
#  ('Elixir', 1041, 130360, 4236591),
#  ('Brightscript', 146, 56568, 2159055),
#  ('ASN.1', 153, 7109, 232889),
#  ('DTrace', 60, 10193, 293998),
#  ('XS', 36, 35491, 855500),
#  ('eC', 66, 3132, 86387),
#  ('Literate CoffeeScript', 77, 10979, 420790),
#  ('KiCad Schematic', 12, 11065, 239702),
#  ('Visual Basic', 436, 78431, 3045558),
#  ('AGS Script', 6, 233, 232363),
#  ('REXX', 2, 103, 3307),
#  ('AutoHotkey', 58, 36265, 1165492),
#  ('Raw token data', 122, 1101831, 87041413),
#  ('Logos', 237, 97855, 2739376),
#  ('JFlex', 20, 3173, 120314),
#  ('Graph Modeling Language', 9, 18790, 177144),
#  ('Apex', 143, 52610, 2523594),
#  ('Tcsh', 10, 2344, 97835),
#  ('Terra', 547, 20446, 441584),
#  ('SubRip Text', 96, 127278, 3214314),
#  ('M', 33, 3357, 109753),
#  ('Processing', 1130, 111774, 3032917),
#  ('LilyPond', 182, 50583, 993782),
#  ('Oz', 1, 232, 7625),
#  ('Idris', 639, 38214, 1178624),
#  ('Modelica', 22, 1216, 53589),
#  ('Hack', 196, 11117, 328266),
#  ('1C Enterprise', 3, 1389, 57011),
#  ('Pickle', 68, 565607, 10285704),
#  ('Smalltalk', 924, 438818, 11701155),
#  ('OpenRC runscript', 75, 4754, 119019),
#  ('CSON', 14, 2255, 56916),
#  ('NewLisp', 39, 4443, 286914),
#  ('Liquid', 42, 2589, 79999),
#  ('IDL', 124, 2215, 68179),
#  ('SourcePawn', 27, 2237, 79849),
#  ('ANTLR', 39, 10033, 244726),
#  ('LLVM', 146, 15934, 833130),
#  ('Gentoo Ebuild', 17, 1488, 40461),
#  ('Ninja', 25, 339, 7182),
#  ('Wavefront Material', 84, 1739, 31348),
#  ('E', 2, 19, 472485),
#  ('Adobe Font Metrics', 137, 190569, 6727458),
#  ('EmberScript', 4, 86, 3564),
#  ('Objective-J', 100, 41953, 1940653),
#  ('Cuda', 899, 238851, 8820027),
#  ('Latte', 155, 7785, 280438),
#  ('POV-Ray SDL', 707, 162293, 8250462),
#  ('Max', 21, 26046, 617069),
#  ('Pure Data', 1076, 151732, 5961702),
#  ('Scilab', 36, 360, 10842),
#  ('SPARQL', 1881, 13291, 274344),
#  ('Web Ontology Language', 13, 25041, 1134812),
#  ('ShaderLab', 57, 5588, 128519),
#  ('Kotlin', 1410, 131744, 4663429),
#  ('Dart', 1699, 230990, 7944792),
#  ('OpenType Feature File', 190, 41014, 2083591),
#  ('G-code', 15, 262770, 5753988),
#  ('Darcs Patch', 1, 530, 20318),
#  ('SMT', 6, 641, 22602),
#  ('SaltStack', 409, 12606, 441884),
#  ('Slash', 67, 3904, 105209),
#  ('Vue', 224, 19676, 557440),
#  ('JSONiq', 14, 363, 17832),
#  ('HTTP', 39, 713, 30890),
#  ('PogoScript', 148, 10056, 303824),
#  ('Slim', 788, 21128, 816199),
#  ('RobotFramework', 36, 3344, 127343),
#  ('MoonScript', 2, 694, 15875),
#  ('edn', 34, 2368, 183406),
#  ('Ragel', 28, 21413, 561262),
#  ('YANG', 6, 2814, 91787),
#  ('World of Warcraft Addon Data', 1, 18, 346),
#  ('BlitzMax', 1, 146, 2387),
#  ('Boo', 6, 154, 4416),
#  ('Bro', 15, 781, 17668),
#  ('Clean', 1, 88, 2878),
#  ('Dylan', 1, 126, 2706),
#  ('ECL', 1, 59, 2599),
#  ('Factor', 1, 384, 10194),
#  ('Fancy', 1, 129, 2581),
#  ('Fantom', 1, 818, 25331),
#  ('Gosu', 2, 113, 2853),
#  ('IRC log', 1, 9, 756),
#  ('Ioke', 1, 25, 469),
#  ('Julia', 1557, 222026, 7308054),
#  ('Lasso', 3, 661, 22604),
#  ('Logtalk', 1, 344, 7260),
#  ('Modula-2', 4, 921, 26342),
#  ('Moocode', 2, 77, 3343),
#  ('Myghty', 3, 228, 4875),
#  ('Nemerle', 1, 88, 1517),
#  ('OpenEdge ABL', 31, 271457, 3954562),
#  ('Python traceback', 3, 40, 2053),
#  ('Redcode', 1, 18, 830),
#  ('Scaml', 25, 240, 5921),
#  ('ShellSession', 1, 20, 320),
#  ('Stan', 1215, 281084, 21970835),
#  ('SystemVerilog', 152, 28230, 1046018),
#  ('Tea', 1, 34, 391),
#  ('XQuery', 27, 14741, 691289),
#  ('Xtend', 82, 8576, 261958),
#  ('Io', 5, 27, 2020),
#  ('Nu', 5, 92, 6447),
#  ('xBase', 29, 4380, 142066),
#  ('ABAP', 2, 793, 25516),
#  ('WebAssembly', 8, 771, 31501),
#  ('Spline Font Database', 8, 63546, 1482220),
#  ('Opa', 11, 780, 21424),
#  ('HCL', 13, 387, 10192),
#  ('GraphQL', 67, 1287, 22342),
#  ('MAXScript', 6, 208, 7463),
#  ('wisp', 28, 9281, 279383),
#  ('PureBasic', 3, 377, 17866),
#  ('Frege', 315, 87442, 3444215),
#  ('Csound Document', 234, 48969, 2897764),
#  ('Clarion', 3, 888, 21333),
#  ('GCC Machine Description', 134, 99505, 3122989),
#  ('COBOL', 23, 1958, 39467),
#  ('ABNF', 1, 389, 11074),
#  ('CartoCSS', 24, 8284, 252937),
#  ('AutoIt', 2, 1041, 42979),
#  ('HTML+EEX', 27, 1928, 67168),
#  ('KiCad Layout', 396, 56768, 3840522),
#  ('KiCad Legacy Layout', 1, 14070, 258399),
#  ('Csound', 5, 266, 6509),
#  ('DNS Zone', 20, 692, 88880),
#  ("Ren'Py", 3, 76212, 2021245),
#  ('nesC', 632, 10852, 226391),
#  ('Hy', 111, 12296, 355141),
#  ('FLUX', 4, 308, 7563),
#  ('BitBake', 1, 33, 1146),
#  ('Type Language', 8, 383, 10420),
#  ('Augeas', 7, 415, 14070),
#  ('Stata', 12, 229, 7880),
#  ('Golo', 152, 11782, 286874),
#  ('Jasmin', 51, 1998, 47026),
#  ('Kit', 1, 27, 884),
#  ('XPages', 3, 489, 20096),
#  ('Mercury', 6, 237, 36375),
#  ('Pic', 3, 34, 1036),
#  ('Metal', 1, 382, 14669),
#  ('Marko', 3, 29, 595),
#  ('XProc', 8, 1205, 58344),
#  ('Ceylon', 30, 1107, 28550),
#  ('UrWeb', 677, 15321, 497275),
#  ('GN', 34, 5150, 141111),
#  ('Genshi', 2, 39, 946),
#  ('Arc', 69, 15300, 506530),
#  ('Elm', 99, 8611, 248025),
#  ('Isabelle ROOT', 1, 14, 515),
#  ('Regular Expression', 5, 62, 3568),
#  ('Alpine Abuild', 1, 61, 1491),
#  ('RenderScript', 1, 44, 1079),
#  ('RAML', 47, 2080, 53689),
#  ('Squirrel', 204, 50516, 1748563),
#  ('Sage', 1, 8, 108),
#  ('Gerber Image', 45, 35843, 625186),
#  ('C2hs Haskell', 164, 20252, 939662),
#  ('PowerBuilder', 2, 784, 25949),
#  ('Filterscript', 3, 75, 2204),
#  ('Bluespec', 1, 202, 8221),
#  ('SQF', 798, 56491, 1897277),
#  ('PureScript', 633, 8980, 157603),
#  ('Cycript', 1, 727, 27606),
#  ('Dogescript', 60, 298, 3824),
#  ("Cap'n Proto", 4, 800, 22504),
#  ('Harbour', 2, 2, 23)]

# %%
df_langs = pd.DataFrame(results, columns=["LANGS", "FILE_COUNT", "LINE_COUNT", "BYTE_COUNT"])
df_langs
# Out:
#                   LANGS  FILE_COUNT  LINE_COUNT  BYTE_COUNT
# 0                     C      144797    54522438  1827653586
# 1              Markdown       76829    10289405   428024795
# 2           Objective-C       44240     5709289   207059642
# 3                  Ruby       90055     7390411   253525221
# 4                  Text       78794    42749997  1942524052
# 5            ApacheConf         895       25420      910753
# 6                  HTML      129750    28014694  1396115755
# 7                  JSON       64035    31782829  1398652042
# 8                   PHP      150002    25112063   885314702
# 9                   XML      124060    41141568  2308770405
# 10                 YAML       39041     3198565   164351763
# 11            Batchfile        3325      208538     6114497
# 12               Gradle        2790      128068     3761315
# 13                  INI       19879     1233262    47845862
# 14                 Java      249343    37973660  1321784643
# 15                Shell       37050     6277121   185067364
# 16              Gherkin        1770      160783     6496025
# 17           JavaScript      258075   114576846  5185386965
# 18             AsciiDoc        1380      211614     8033679
# 19              M4Sugar        2792     1447128    50495517
# 20             Makefile       16015     1395395    49370192
# 21                  Nim          80        9944      334258
# 22                 Perl       18601     3223969   140075798
# 23                 fish          78        4842      154454
# 24                   Go       35753    11173501   352909472
# 25        Unity3D Asset        4998      329400    16918254
# 26                  CSV        2718    10963243   808682328
# 27                 RDoc         264       42366     1550121
# 28                  CSS       34537    13625190   610159098
# 29      Gettext Catalog       12313    13459308   381510653
# ..                  ...         ...         ...         ...
# 318              XPages           3         489       20096
# 319             Mercury           6         237       36375
# 320                 Pic           3          34        1036
# 321               Metal           1         382       14669
# 322               Marko           3          29         595
# 323               XProc           8        1205       58344
# 324              Ceylon          30        1107       28550
# 325               UrWeb         677       15321      497275
# 326                  GN          34        5150      141111
# 327              Genshi           2          39         946
# 328                 Arc          69       15300      506530
# 329                 Elm          99        8611      248025
# 330       Isabelle ROOT           1          14         515
# 331  Regular Expression           5          62        3568
# 332       Alpine Abuild           1          61        1491
# 333        RenderScript           1          44        1079
# 334                RAML          47        2080       53689
# 335            Squirrel         204       50516     1748563
# 336                Sage           1           8         108
# 337        Gerber Image          45       35843      625186
# 338        C2hs Haskell         164       20252      939662
# 339        PowerBuilder           2         784       25949
# 340        Filterscript           3          75        2204
# 341            Bluespec           1         202        8221
# 342                 SQF         798       56491     1897277
# 343          PureScript         633        8980      157603
# 344             Cycript           1         727       27606
# 345          Dogescript          60         298        3824
# 346         Cap'n Proto           4         800       22504
# 347             Harbour           2           2          23
#
# [348 rows x 4 columns]

# %%
top10 = df_langs.sort_values("FILE_COUNT", ascending=False).head(10)
top10
# Out:
#          LANGS  FILE_COUNT  LINE_COUNT  BYTE_COUNT
# 17  JavaScript      258075   114576846  5185386965
# 14        Java      249343    37973660  1321784643
# 35         C++      156016    47093520  1612789922
# 8          PHP      150002    25112063   885314702
# 0            C      144797    54522438  1827653586
# 6         HTML      129750    28014694  1396115755
# 30      Python      124682    22927920   959218946
# 9          XML      124060    41141568  2308770405
# 3         Ruby       90055     7390411   253525221
# 4         Text       78794    42749997  1942524052

# %% [markdown]
# ### Normalization

# %%
values_type = ["FILE_COUNT", "LINE_COUNT", "BYTE_COUNT"]
for val_type in values_type:
    top10[val_type] /= top10[val_type].max()
top10
# Out:
#          LANGS  FILE_COUNT  LINE_COUNT  BYTE_COUNT
# 17  JavaScript    1.000000    1.000000    1.000000
# 14        Java    0.966165    0.331425    0.254906
# 35         C++    0.604537    0.411021    0.311026
# 8          PHP    0.581234    0.219172    0.170733
# 0            C    0.561066    0.475859    0.352462
# 6         HTML    0.502761    0.244506    0.269240
# 30      Python    0.483123    0.200110    0.184985
# 9          XML    0.480713    0.359074    0.445246
# 3         Ruby    0.348949    0.064502    0.048892
# 4         Text    0.305314    0.373112    0.374615

# %% [markdown]
# ### Visualization

# %%
langs = list(top10["LANGS"])
langs
# Out:
# ['JavaScript',
#  'Java',
#  'C++',
#  'PHP',
#  'C',
#  'HTML',
#  'Python',
#  'XML',
#  'Ruby',
#  'Text']

# %%
values = [[] for _ in range(len(values_type))]
for i in range(len(langs)):
    for j, val_type in enumerate(values_type):
        values[j].append(top10.iloc[i][val_type])

# %%
figure(figsize=(12, 6))
ax = subplot(111)

x = arange(1, 11)
ax.bar(x-0.2, values[0], width=0.2, align='center', label="Files")
ax.bar(x, values[1], width=0.2, align='center', label="Lines")
ax.bar(x+0.2, values[2], width=0.2, align='center', label="Bytes")

ax.set_xticks(x)
langs[0] = "JS"
ax.set_xticklabels(langs, fontsize=18)
ax.tick_params(axis='both', which='both',length=0)
ax.set_yticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

legend(fontsize=24).get_frame().set_linewidth(0.0)
tight_layout()
savefig("lang_stats.eps")
